# %%
# encoding=utf-8
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']

f = open('clean_repair-trajectory_new_final.txt', 'r')
now = []
nowx = []
repair = []
repairx = []
index = 0
line = f.readline()
while line: 
    lines = line.split(',')
    n = len(lines[3])
    if n > 3:
        repair.append(float(lines[0]))
        repairx.append(index)
    else:
        now.append(float(lines[0]))
        nowx.append(index)
    line = f.readline()
    index += 1
f.close()

plt.scatter(nowx, now, s=1, marker='.')
# plt.scatter(repairx, repair, s=1, marker='.')
# plt.legend()  # 让图例生效
# plt.xticks(x, names, rotation=45)
# plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"AIS序列") #X轴标签
plt.ylabel("经度(°)") #Y轴标签
plt.title("") #标题
plt.savefig("lon_reapir_final_before.png")
plt.show()

# %%
# encoding=utf-8
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']

f = open('clean_repair-trajectory_new_final.txt', 'r')
now = []
nowx = []
repair = []
repairx = []
index = 0
line = f.readline()
while line: 
    lines = line.split(',')
    n = len(lines[3])
    now.append(float(lines[0]))
    nowx.append(index)
    line = f.readline()
    index += 1
f.close()

plt.scatter(nowx, now, s=1, marker='.')
# plt.scatter(repairx, repair, s=1, marker='.')
# plt.legend()  # 让图例生效
# plt.xticks(x, names, rotation=45)
# plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"AIS序列") #X轴标签
plt.ylabel("经度(°)") #Y轴标签
plt.title("") #标题
plt.savefig("lon_reapir_final_after.png")
plt.show()

# %%
# encoding=utf-8
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']

f = open('clean_repair-trajectory_new_final.txt', 'r')
now = []
nowx = []
repair = []
repairx = []
index = 0
line = f.readline()
while line: 
    lines = line.split(',')
    n = len(lines[3])
    if n > 3:
        repair.append(float(lines[1]))
        repairx.append(index)
    else:
        now.append(float(lines[1]))
        nowx.append(index)
    line = f.readline()
    index += 1
f.close()

plt.scatter(nowx, now, s=1, marker='.')
# plt.scatter(repairx, repair, s=1, marker='.')
# plt.legend()  # 让图例生效
# plt.xticks(x, names, rotation=45)
# plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"AIS序列") #X轴标签
plt.ylabel("纬度(°)") #Y轴标签
plt.title("") #标题
plt.savefig("lan_reapir_final_before.png")
plt.show()

# %%
# encoding=utf-8
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']

f = open('clean_repair-trajectory_new_final.txt', 'r')
now = []
nowx = []
repair = []
repairx = []
index = 0
line = f.readline()
while line: 
    lines = line.split(',')
    n = len(lines[3])
    now.append(float(lines[1]))
    nowx.append(index)
    line = f.readline()
    index += 1
f.close()

plt.scatter(nowx, now, s=1, marker='.')
# plt.scatter(repairx, repair, s=1, marker='.')
# plt.legend()  # 让图例生效
# plt.xticks(x, names, rotation=45)
# plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"AIS序列") #X轴标签
plt.ylabel("纬度(°)") #Y轴标签
plt.title("") #标题
plt.savefig("lan_reapir_final_after.png")
plt.show()

# %%
# encoding=utf-8
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']

f = open('clean_repair-trajectory_new_final.txt', 'r')
now = []
nowx = []
repair = []
repairx = []
index = 0
line = f.readline()
while line: 
    lines = line.split(',')
    n = len(lines[3])
    if n > 3:
        repair.append(float(lines[2]))
        repairx.append(index)
    else:
        now.append(float(lines[2]))
        nowx.append(index)
    line = f.readline()
    index += 1
f.close()

plt.scatter(nowx, now, s=1, marker='.')
# plt.scatter(repairx, repair, s=1, marker='.')
# plt.legend()  # 让图例生效
# plt.xticks(x, names, rotation=45)
# plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"AIS序列") #X轴标签
plt.ylabel("航速(nmi/h)") #Y轴标签
plt.title("") #标题
plt.savefig("v_reapir_final_before.png")
plt.show()

# %%
# encoding=utf-8
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']

f = open('clean_repair-trajectory_new_final.txt', 'r')
now = []
nowx = []
repair = []
repairx = []
index = 0
line = f.readline()
while line: 
    lines = line.split(',')
    n = len(lines[3])
    now.append(float(lines[2]))
    nowx.append(index)
    line = f.readline()
    index += 1
f.close()

plt.scatter(nowx, now, s=1, marker='.')
# plt.scatter(repairx, repair, s=1, marker='.')
# plt.legend()  # 让图例生效
# plt.xticks(x, names, rotation=45)
# plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"AIS序列") #X轴标签
plt.ylabel("航速(nmi/h)") #Y轴标签
plt.title("") #标题
plt.savefig("v_reapir_final_after.png")
plt.show()

# %%
# encoding=utf-8
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']

f = open('clean_repair-trajectory_new_final.txt', 'r')
now = []
nowx = []
repair = []
repairx = []
index = 0
line = f.readline()
while line: 
    lines = line.split(',')
    n = len(lines[3])
    if n > 3:
        repair.append(float(lines[3]))
        repairx.append(index)
    else:
        now.append(float(lines[3]))
        nowx.append(index)
    line = f.readline()
    index += 1
f.close()

plt.scatter(nowx, now, s=1, marker='.')
# plt.scatter(repairx, repair, s=1, marker='.')
# plt.legend()  # 让图例生效
# plt.xticks(x, names, rotation=45)
# plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"AIS序列") #X轴标签
plt.ylabel("航向(°)") #Y轴标签
plt.title("") #标题
plt.savefig("cog_reapir_final_before.png")
plt.show()

# %%
# encoding=utf-8
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']

f = open('clean_repair-trajectory_new_final.txt', 'r')
now = []
nowx = []
repair = []
repairx = []
index = 0
line = f.readline()
while line: 
    lines = line.split(',')
    n = len(lines[3])
    now.append(float(lines[3]))
    nowx.append(index)
    line = f.readline()
    index += 1
f.close()

plt.scatter(nowx, now, s=1, marker='.')
# plt.scatter(repairx, repair, s=1, marker='.')
# plt.legend()  # 让图例生效
# plt.xticks(x, names, rotation=45)
# plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"AIS序列") #X轴标签
plt.ylabel("航向(°)") #Y轴标签
plt.title("") #标题
plt.savefig("cog_reapir_final_after.png")
plt.show()
