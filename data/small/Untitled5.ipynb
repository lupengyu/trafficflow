# %%
# encoding=utf-8
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']

f = open('create(true).txt', 'r')
line = f.readline()
v = []
while line: 
#     print(line, end = '')
    lines = line.split(',')
#     print(lines)
#     print(lines)
    if len(lines) == 4:
        v.append(float(lines[2]))
    line = f.readline() 
f.close() 

f = open('cleandata_repair.txt', 'r')
line = f.readline()
v2 = []
while line: 
#     print(line, end = '')
    lines = line.split(',')
#     print(lines)
#     print(lines)
    if len(lines) == 4:
        v2.append(float(lines[2]))
    line = f.readline() 
f.close() 

print(len(v))
print(len(v2))

names = ['5', '10', '15', '20', '25']
x = range(len(v))
y = v
y2 = v2
#plt.plot(x, y, 'ro-')
#plt.plot(x, y1, 'bo-')
#pl.xlim(-1, 11)  # 限定横轴的范围
# plt.ylim(-1, 110)  # 限定纵轴的范围
plt.plot(x, y, label=u'模拟数据')
plt.plot(x, y2, linestyle=':', label=u'修复后数据')
plt.legend()  # 让图例生效
# plt.xticks(x, names, rotation=45)
# plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"AIS序列") #X轴标签
plt.ylabel("速度(nmi/h)") #Y轴标签
plt.title("") #标题
plt.savefig("v_create.png")
plt.show()

# fig.tight_layout()
# Out:
# 633
# 633

# %%
# encoding=utf-8
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']

f = open('create(true).txt', 'r')
line = f.readline()
cog = []
while line: 
#     print(line, end = '')
    lines = line.split(',')
#     print(lines)
#     print(lines)
    if len(lines) == 4:
        c = lines[3].split('\n')
        cog.append(float(c[0]))
    line = f.readline() 
f.close() 

f = open('cleandata_repair.txt', 'r')
line = f.readline()
cog2 = []
while line: 
#     print(line, end = '')
    lines = line.split(',')
#     print(lines)
#     print(lines)
    if len(lines) == 4:
        c = lines[3].split('\n')
        cog2.append(float(c[0]))
    line = f.readline() 
f.close() 

print(len(cog))

x = range(len(cog))
y = cog
y2 = cog2
#plt.plot(x, y, 'ro-')
#plt.plot(x, y1, 'bo-')
#pl.xlim(-1, 11)  # 限定横轴的范围
# plt.ylim(-1, 1)  # 限定纵轴的范围
plt.plot(x, y, label=u'模拟数据')
plt.plot(x, y2, linestyle=':', label=u'修复后数据')
plt.legend()  # 让图例生效
plt.rcParams['axes.unicode_minus']=False
# plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"AIS序列") #X轴标签
plt.ylabel("航向（°）") #Y轴标签
plt.title("") #标题
plt.savefig("cog_create.png")
plt.show()
# Out:
# 633

# %%
# encoding=utf-8
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']

f = open('create(true).txt', 'r')
line = f.readline()
v = []
while line: 
#     print(line, end = '')
    lines = line.split(',')
#     print(lines)
#     print(lines)
    if len(lines) == 4:
        v.append(float(lines[0]))
    line = f.readline() 
f.close() 

f = open('cleandata_repair.txt', 'r')
line = f.readline()
v2 = []
while line: 
#     print(line, end = '')
    lines = line.split(',')
#     print(lines)
#     print(lines)
    if len(lines) == 4:
        v2.append(float(lines[0]))
    line = f.readline() 
f.close() 

print(len(v))
print(len(v2))

names = ['5', '10', '15', '20', '25']
x = range(len(v))
y = v
y2 = v2
#plt.plot(x, y, 'ro-')
#plt.plot(x, y1, 'bo-')
#pl.xlim(-1, 11)  # 限定横轴的范围
# plt.ylim(-1, 110)  # 限定纵轴的范围
plt.plot(x, y, label=u'模拟数据')
plt.plot(x, y2, linestyle=':', label=u'修复后数据')
plt.legend()  # 让图例生效
# plt.xticks(x, names, rotation=45)
# plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"AIS序列") #X轴标签
plt.ylabel("经度(°)") #Y轴标签
plt.title("") #标题
plt.savefig("lon_create.png")
plt.show()

# fig.tight_layout()
# Out:
# 633
# 633

# %%
# encoding=utf-8
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']

f = open('create(true).txt', 'r')
line = f.readline()
v = []
while line: 
#     print(line, end = '')
    lines = line.split(',')
#     print(lines)
#     print(lines)
    if len(lines) == 4:
        v.append(float(lines[1]))
    line = f.readline() 
f.close() 

f = open('cleandata_repair.txt', 'r')
line = f.readline()
v2 = []
while line: 
#     print(line, end = '')
    lines = line.split(',')
#     print(lines)
#     print(lines)
    if len(lines) == 4:
        v2.append(float(lines[1]))
    line = f.readline() 
f.close() 

print(len(v))
print(len(v2))

names = ['5', '10', '15', '20', '25']
x = range(len(v))
y = v
y2 = v2
#plt.plot(x, y, 'ro-')
#plt.plot(x, y1, 'bo-')
#pl.xlim(-1, 11)  # 限定横轴的范围
# plt.ylim(-1, 110)  # 限定纵轴的范围
plt.plot(x, y, label=u'模拟数据')
plt.plot(x, y2, linestyle=':', label=u'修复后数据')
plt.legend()  # 让图例生效
# plt.xticks(x, names, rotation=45)
# plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"AIS序列") #X轴标签
plt.ylabel("纬度(°)") #Y轴标签
plt.title("") #标题
plt.savefig("lan_create.png")
plt.show()

# fig.tight_layout()
# Out:
# 633
# 633
