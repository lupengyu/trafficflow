# %%
# encoding=utf-8
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']
f = open('412596777.txt', 'r')
line = f.readline()
v = []
while line: 
#     print(line, end = '')
    lines = line.split(',')
#     print(lines)
#     print(lines)
    if len(lines) == 5:
        v.append(float(lines[2]))
    line = f.readline() 
f.close() 


names = ['5', '10', '15', '20', '25']
x = range(len(v))
y = v
#plt.plot(x, y, 'ro-')
#plt.plot(x, y1, 'bo-')
#pl.xlim(-1, 11)  # 限定横轴的范围
# plt.ylim(-1, 110)  # 限定纵轴的范围
plt.plot(x, y)
# plt.legend()  # 让图例生效
# plt.xticks(x, names, rotation=45)
# plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"AIS序列") #X轴标签
plt.ylabel("速度(nmi/h)") #Y轴标签
plt.title("") #标题
plt.savefig("v_412596777.png")
plt.show()

# fig.tight_layout()

# %%
f = open('412596777.txt', 'r')
line = f.readline()
v = []
alist = []
pre = 7.2
time = 10.0
pretime = -817624
while line: 
#     print(line, end = '')
    lines = line.split(',')
#     print(lines)
#     print(lines)
    if len(lines) == 5:
        v2 = float(lines[2])
        time = float(lines[4].split('\n')[0])
#         print(time, pretime)
        if time == pretime:
            alist.append(0)
        else:
            a = (v2 - pre) / (time - pretime)
            pre = v2
            pretime = time
            alist.append(a)
    line = f.readline() 
f.close() 
# print(alist)

x = range(len(alist))
y = alist
#plt.plot(x, y, 'ro-')
#plt.plot(x, y1, 'bo-')
#pl.xlim(-1, 11)  # 限定横轴的范围
# plt.ylim(-1, 1)  # 限定纵轴的范围
plt.plot(x, y)
plt.rcParams['axes.unicode_minus']=False
# plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"AIS序列") #X轴标签
plt.ylabel("加速度(m/s2)") #Y轴标签
plt.title("") #标题
plt.savefig("a_412596777.png")
plt.show()

# %%
f = open('412596777.txt', 'r')
line = f.readline()
cog = []
while line: 
#     print(line, end = '')
    lines = line.split(',')
#     print(lines)
#     print(lines)
    if len(lines) == 5:
        c = lines[3]
        cog.append(float(c))
    line = f.readline() 
f.close() 

x = range(len(cog))
y = cog
#plt.plot(x, y, 'ro-')
#plt.plot(x, y1, 'bo-')
#pl.xlim(-1, 11)  # 限定横轴的范围
# plt.ylim(-1, 1)  # 限定纵轴的范围
plt.plot(x, y)
plt.rcParams['axes.unicode_minus']=False
# plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"AIS序列") #X轴标签
plt.ylabel("航向（°）") #Y轴标签
plt.title("") #标题
plt.savefig("cog_412596777.png")
plt.show()

# %%
f = open('412596777.txt', 'r')
line = f.readline()
v = []
rate = []
pre = 263
pretime = -817623
while line: 
#     print(line, end = '')
    lines = line.split(',')
#     print(lines)
#     print(lines)
    if len(lines) == 5:
        time = float(lines[4].split('\n')[0])
#         print(time, pretime)
        if time == pretime:
            rate.append(0)
        else:
            c = float(lines[3])
            ra = (c - pre) / (time - pretime)
            pre = c
            if ra < 0:
                ra = ra * -1
            rate.append(ra)
    line = f.readline() 
f.close() 
# print(alist)

x = range(len(rate))
y = rate
#plt.plot(x, y, 'ro-')
#plt.plot(x, y1, 'bo-')
#pl.xlim(-1, 11)  # 限定横轴的范围
# plt.ylim(-1, 1)  # 限定纵轴的范围
plt.plot(x, y)
plt.rcParams['axes.unicode_minus']=False
# plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"AIS序列") #X轴标签
plt.ylabel("转向速率(°/s)") #Y轴标签
plt.title("") #标题
plt.savefig("rate_412596777_1.png")
plt.show()

# %%
f = open('412596777.txt', 'r')
line = f.readline()
v = []
rate = []
pre = 263
pretime = -817623
while line: 
#     print(line, end = '')
    lines = line.split(',')
#     print(lines)
#     print(lines)
    if len(lines) == 5:
        time = float(lines[4].split('\n')[0])
#         print(time, pretime)
        if time == pretime:
            rate.append(0)
        else:
            c = float(lines[3])
            tmp = c - pre
            if tmp < 0:
                tmp = tmp * -1
            up = tmp
            if tmp > 180:
                up = 360 - tmp
            ra = up / (time - pretime)
            pre = c
            if ra < 0:
                ra = ra * -1
            rate.append(ra)
    line = f.readline() 
f.close() 
# print(alist)

x = range(len(rate))
y = rate
#plt.plot(x, y, 'ro-')
#plt.plot(x, y1, 'bo-')
#pl.xlim(-1, 11)  # 限定横轴的范围
# plt.ylim(-1, 1)  # 限定纵轴的范围
plt.plot(x, y)
plt.rcParams['axes.unicode_minus']=False
# plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"AIS序列") #X轴标签
plt.ylabel("转向速率(°/s)") #Y轴标签
plt.title("") #标题
plt.savefig("rate_412596777_2.png")
plt.show()
